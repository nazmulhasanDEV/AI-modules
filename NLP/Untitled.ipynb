# %% [markdown]
# ### N-grams: An N-gram is simply a sequence of N consecutive items (usually words or characters) from a text.
# "I am learning NLP"
# Unigram (1-gram): ["I", "am", "learning", "NLP"]
#
# Bigram (2-gram): [("I", "am"), ("am", "learning"), ("learning", "NLP")]
#
# Trigram (3-gram): [("I", "am", "learning"), ("am", "learning", "NLP")]

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
token =['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']

# %%
# unigrams: n=1
unigrams = (pd.Series(nltk.ngrams(token, 1)).value_counts()) 
print(unigrams)
# Out:
# (to,)               7
# (of,)               6
# (the,)              4
# (in,)               4
# (and,)              3
#                    ..
# (perform,)          1
# (computers,)        1
# (enabling,)         1
# (sophisticated,)    1
# (be,)               1
# Name: count, Length: 79, dtype: int64

# %%
unigrams[0:10].sort_values().plot.barh(color='lightsalmon', width=.9, figsize=(12, 8))
plt.title('10 Most Frequently Occuring Unigrams')
plt.ylabel('Unigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %%
# bigrams: n=2
bigrams = (pd.Series(nltk.ngrams(tokenbigrams[0:10].sort_values().plot.barh(color='skyblue', width=.9, figsize=(12, 8))
plt.title('10 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('# of Occurances'), 2)).value_counts()) 
print(bigrams)
# Out:
#   Cell In[57], line 2
#     bigrams = (pd.Series(nltk.ngrams(tokenbigrams[0:10].sort_values().plot.barh(color='skyblue', width=.9, figsize=(12, 8))
#                                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
